# %% [markdown]
# # Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 50
sample_std_dev = 5
sample_size = 100

standard_error = sample_std_dev / (sample_size ** 0.5)
z_score = stats.norm.ppf(0.975)
margin_of_error = z_score * standard_error
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# # Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed_blue_count = 20
observed_orange_count = 20
observed_green_count = 20
observed_yellow_count = 10
observed_red_count = 10
observed_brown_count = 20
total_mms = observed_blue_count + observed_orange_count + observed_green_count + observed_yellow_count + observed_red_count + observed_brown_count

observed = [observed_blue_count, observed_orange_count, observed_green_count,observed_yellow_count, observed_red_count, observed_brown_count]
expected = [0.20 * total_mms, 0.20 * total_mms, 0.20 * total_mms,    0.10 * total_mms, 0.10 * total_mms, 0.20 * total_mms]

chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. The distribution of colors of M&Ms in the bag does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis. The distribution of colors of M&Ms in the bag matches the expected distribution.")
# Out:
# Fail to reject the null hypothesis. The distribution of colors of M&Ms in the bag matches the expected distribution.

# %% [markdown]
# # Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[20, 15], [10, 25], [15, 20]])
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
# Out:
# Chi-square Statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %% [markdown]
# # Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import scipy.stats as stats

n = 500
x = 60
p_hat = x / n
standard_error = (p_hat * (1 - p_hat) / n) ** 0.5

margin_of_error = z_score * standard_error
confidence_interval = (p_hat - margin_of_error, p_hat + margin_of_error)
print("95% Confidence Interval for the true proportion of smokers in the population:", confidence_interval)
# Out:
# 95% Confidence Interval for the true proportion of smokers in the population: (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# #  Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats
sample_mean = 75
sample_std_dev = 12
sample_size = 100

standard_error = sample_std_dev / (sample_size ** 0.5)

z_score = stats.norm.ppf(0.95 + (1 - 0.90) / 2)  
margin_of_error = z_score * standard_error
onfidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# # Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = 10

x = np.linspace(0, 30, 1000)
chi2_pdf = stats.chi2.pdf(x, df)

plt.plot(x, chi2_pdf, 'b-', label='Chi-square PDF (df=10)')
plt.xlabel('Chi-square Statistic')
plt.ylabel('Probability Density Function (PDF)')
plt.title('Chi-square Distribution with 10 Degrees of Freedom')

plt.fill_between(x, chi2_pdf, where=(x >= 15), color='gray', alpha=0.5, label='Chi-square statistic of 15')
plt.legend()
plt.show()

# %% [markdown]
# #  Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
import scipy.stats as stats

n = 1000
x = 520
p_hat = x / n

standard_error = (p_hat * (1 - p_hat) / n) ** 0.5
z_score = stats.norm.ppf(0.995)
margin_of_error = z_score * standard_error
confidence_interval = (p_hat - margin_of_error, p_hat + margin_of_error)

print("99% Confidence Interval for the true proportion of people who prefer Coke:", confidence_interval)
# Out:
# 99% Confidence Interval for the true proportion of people who prefer Coke: (0.4793051576779699, 0.5606948423220302)

# %% [markdown]
# #  Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
from scipy.stats import chisquare

observed_tails = 45
total_trials = 100
expected_tails = total_trials / 2  
observed = [observed_tails, total_trials - observed_tails]
expected = [expected_tails, total_trials - expected_tails]

chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. The coin is biased.")
else:
    print("Fail to reject the null hypothesis. The coin is fair.")
# Out:
# Fail to reject the null hypothesis. The coin is fair.

# %% [markdown]
# #  Q9. A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between smoking status and lung cancer diagnosis.

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[60, 140],  [30, 170]])
chi2_stat, p_value, dof, expected = chi2_contingency(observed)
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between smoking status and lung cancer diagnosis.")

print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Reject the null hypothesis. There is a significant association between smoking status and lung cancer diagnosis.
# Chi-square Statistic: 12.057347670250895
# p-value: 0.0005158863863703744
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[ 45. 155.]
#  [ 45. 155.]]

# %% [markdown]
# #  Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between chocolate preference and country of origin.

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[200, 150, 150], [225, 175, 100]])
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

alpha = 0.01
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between chocolate preference and country of origin.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between chocolate preference and country of origin.")

print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Reject the null hypothesis. There is a significant association between chocolate preference and country of origin.
# Chi-square Statistic: 13.393665158371041
# p-value: 0.0012348168997745915
# Degrees of Freedom: 2
# Expected Frequencies Table:
# [[212.5 162.5 125. ]
#  [212.5 162.5 125. ]]

# %% [markdown]
# # Q11. A random sample of 30 people was selected from a population with an unknown mean and standard deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a significance level of 0.05.

# %%
from scipy.stats import ttest_1samp

sample_mean = 72
sample_std_dev = 10
sample_size = 30

hypothesized_mean = 70
t_statistic, p_value = ttest_1samp((sample_mean,), hypothesized_mean)
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis. The population mean is not significantly different from 70.")

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# Fail to reject the null hypothesis. The population mean is not significantly different from 70.
# t-statistic: nan
# p-value: nan
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_stats_py.py:1081: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_stats_py.py:1081: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
